# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_sleep = pd.read_excel("df_sleep_with_family.xlsx")

df_sleep.head()
# Out:
#    TotalSleep  Awake  NonDreaming  Dreaming        Order        Family  \
# 0         3.3   20.7          NaN       NaN  Proboscidea  Elephantidae
# 1         8.3   15.7          6.3       2.0     Rodentia    Nesomyidae
# 2         8.7   15.3          NaN       NaN     Rodentia       Muridae
# 3        12.5   11.5          NaN       NaN    Carnivora       Canidae
# 4        16.6    7.4          NaN       NaN     Rodentia     Sciuridae
#
#           Genus                    Species   Vore Conservation    BodyWt  \
# 0     Loxodonta           African elephant  herbi           vu  6654.000
# 1    Cricetomys  African giant pouched rat   omni          NaN     1.000
# 2     Rhabdomys      African striped mouse   omni          NaN     0.044
# 3        Vulpes                 Arctic fox  carni          NaN     3.380
# 4  Spermophilus     Arctic ground squirrel  herbi           lc     0.920
#
#    BrainWt  LifeSpan  Gestation  Predation  Exposure  Danger
# ...

# %%
df_biological_ecological = df_sleep[['BodyWt', 'BrainWt', 'LifeSpan', 'Gestation', 'Predation', 'Exposure', 'Danger']]

df_biological_ecological.head()
# Out:
#      BodyWt  BrainWt  LifeSpan  Gestation  Predation  Exposure  Danger
# 0  6654.000   5712.0      38.6      645.0        3.0       5.0     3.0
# 1     1.000      6.6       4.5       42.0        3.0       1.0     3.0
# 2     0.044      0.0       NaN        NaN        NaN       NaN     NaN
# 3     3.380     44.5      14.0       60.0        1.0       1.0     1.0
# 4     0.920      5.7       NaN       25.0        5.0       2.0     3.0

# %%
df_no_null = df_biological_ecological.dropna()

df_no_null.shape
# Out:
# (51, 7)

# %%
df_no_null
# Out:
#       BodyWt  BrainWt  LifeSpan  Gestation  Predation  Exposure  Danger
# 0   6654.000  5712.00      38.6      645.0        3.0       5.0     3.0
# 1      1.000     6.60       4.5       42.0        3.0       1.0     3.0
# 3      3.380    44.50      14.0       60.0        1.0       1.0     1.0
# 5   2547.000  4603.00      69.0      624.0        3.0       5.0     4.0
# 6     25.235   180.00      27.0      180.0        4.0       4.0     4.0
# 7      0.023     0.30      19.0       35.0        1.0       1.0     1.0
# 9    207.501   169.00      30.4      392.0        4.0       5.0     4.0
# 12    52.200   440.00      50.0      230.0        1.0       1.0     1.0
# 13     0.420     6.40       7.0      112.0        5.0       4.0     4.0
# 16   600.000   423.00      30.0      281.0        5.0       5.0     5.0
# 21     3.300    25.60      28.0       63.0        1.0       2.0     1.0
# 22   187.000   419.00      40.0      365.0        5.0       5.0     5.0
# ...

# %%
plt.figure(figsize=(16, 6))

heatmap = sns.heatmap(df_no_null.corr(), vmin=-1, vmax=1, annot=True)

heatmap
# Out:
# <AxesSubplot:>
